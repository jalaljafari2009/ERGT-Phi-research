# %% [markdown]
# # M2-E005/v001 — Validate an intervention-driven answer and path challenge target with frozen matched readouts
#
# این نوت‌بوک فقط برای پروتکل ثبت‌شدهٔ همین نسخه است. هدف، فرضیه، ورودی‌ها،
# معیارهای پذیرش و دستور دقیق در زیر ثبت شده‌اند. تغییر روش، seed، داده یا آستانه
# نیاز به revision تازه در ریپو دارد. Run all اجرای همین آزمایش را آغاز می‌کند.
#
# **مرحله:** M2 — **نوع:** research
#
# **فرضیه:** Preregistered scenario interventions on the frozen native model will create nonzero, finite variation in answer-margin and event/path outcomes in both locked development windows. Capacity-matched readouts trained only on historical M0 fit can then measure how much answer/path sensitivity is present in raw, Q, no-phase and frozen-phase representations without using fresh targets for training or claiming Phase superiority.
#
# **ارجاع هدف:** docs/MATHEMATICAL_SPEC.md sections 5, 14, 15 and 17; docs/SPEC_Q_ANCHOR_ADDENDUM.md; docs/OPERATIONAL_ROADMAP_FA.md; ADR-0012
#
# ```json
# {
#   "hypothesis": "Preregistered scenario interventions on the frozen native model will create nonzero, finite variation in answer-margin and event/path outcomes in both locked development windows. Capacity-matched readouts trained only on historical M0 fit can then measure how much answer/path sensitivity is present in raw, Q, no-phase and frozen-phase representations without using fresh targets for training or claiming Phase superiority.",
#   "goal_reference": "docs/MATHEMATICAL_SPEC.md sections 5, 14, 15 and 17; docs/SPEC_Q_ANCHOR_ADDENDUM.md; docs/OPERATIONAL_ROADMAP_FA.md; ADR-0012",
#   "parent": {
#     "experiment_id": "M2-E004",
#     "revision": "v001"
#   },
#   "command": [
#     "{python}",
#     "-B",
#     "scripts/run_m2_answer_path_challenge.py",
#     "--output",
#     "runs/m2_answer_path_challenge",
#     "--reference-checkpoint",
#     "research/inputs/M2-E003/v001/native_ergt_training.pt",
#     "--phase-checkpoint",
#     "research/inputs/M2-E003/v001/selected_m2_q_v2.pt",
#     "--reference-metadata",
#     "research/legacy/LEGACY-M0/evidence/imported_m0/m0_single_seed_reference",
#     "--contract",
#     "configs/m2_answer_path_challenge_v1.json",
#     "--fresh-lock",
#     "configs/m2_e003_fresh_development_lock.json",
#     "--experiment-protocol",
#     "research/experiments/M2-E005/v001/protocol.json"
#   ],
#   "inputs": [
#     {
#       "path": "research/inputs/M2-E003/v001/native_ergt_training.pt",
#       "sha256": "82d1220ee4bcc7f721e8159ea3515fe5992a92a184a611db6223e292a14eb065",
#       "uri": "copy://M2-E002/v001/native_ergt_training.pt"
#     },
#     {
#       "path": "research/inputs/M2-E003/v001/selected_m2_q_v2.pt",
#       "sha256": "8056322cf7c58dd5845f87bf6a89ccbb2ddd76c2d06933a3b5f2fa533688a234",
#       "uri": "artifact://M2-E002/v001/20260921T210953Z-48abf488-local/selected_full_state.pt"
#     }
#   ],
#   "output_paths": [
#     "runs/m2_answer_path_challenge"
#   ],
#   "required_artifacts": [
#     "runs/m2_answer_path_challenge/result.json",
#     "runs/m2_answer_path_challenge/input_integrity.json",
#     "runs/m2_answer_path_challenge/historical_fit_challenge_rows.jsonl",
#     "runs/m2_answer_path_challenge/fresh_challenge_rows.jsonl",
#     "runs/m2_answer_path_challenge/readout_predictions.jsonl",
#     "runs/m2_answer_path_challenge/readout_checkpoints.pt",
#     "runs/m2_answer_path_challenge/m2_answer_path_handoff.json"
#   ],
#   "gates": [
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "challenge_complete",
#       "op": "eq",
#       "pointer": "/challenge_panel_complete",
#       "value": true
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "challenge_support_validated",
#       "op": "eq",
#       "pointer": "/challenge_panel_suitable_for_answer_path_readout",
#       "value": true
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "window_1_failures",
#       "op": "ge",
#       "pointer": "/windows/window_1/support/answer_failures",
#       "value": 4
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "window_2_failures",
#       "op": "ge",
#       "pointer": "/windows/window_2/support/answer_failures",
#       "value": 4
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "window_1_successes",
#       "op": "ge",
#       "pointer": "/windows/window_1/support/answer_successes",
#       "value": 4
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "window_2_successes",
#       "op": "ge",
#       "pointer": "/windows/window_2/support/answer_successes",
#       "value": 4
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "window_1_chain_degradation",
#       "op": "ge",
#       "pointer": "/windows/window_1/support/event_chain_degradations",
#       "value": 4
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "window_2_chain_degradation",
#       "op": "ge",
#       "pointer": "/windows/window_2/support/event_chain_degradations",
#       "value": 4
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "window_1_margin_variation",
#       "op": "ge",
#       "pointer": "/windows/window_1/support/response_margin_drop_std",
#       "value": 1e-06
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "window_2_margin_variation",
#       "op": "ge",
#       "pointer": "/windows/window_2/support/response_margin_drop_std",
#       "value": 1e-06
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "fresh_targets_not_used",
#       "op": "eq",
#       "pointer": "/fresh_targets_used_for_training_selection_or_tuning",
#       "value": false
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "fresh_lock_match",
#       "op": "eq",
#       "pointer": "/integrity/fresh_lock_match",
#       "value": true
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "raw_text_disjoint",
#       "op": "eq",
#       "pointer": "/integrity/raw_text_disjoint_from_m0_training",
#       "value": true
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "pair_disjoint",
#       "op": "eq",
#       "pointer": "/integrity/counterfactual_pair_disjoint_from_m0_training",
#       "value": true
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "windows_pair_disjoint",
#       "op": "eq",
#       "pointer": "/integrity/confirmation_windows_pair_disjoint",
#       "value": true
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "fit_monitor_disjoint",
#       "op": "eq",
#       "pointer": "/integrity/historical_fit_monitor_disjoint",
#       "value": true
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "historical_training_only",
#       "op": "eq",
#       "pointer": "/integrity/historical_targets_only_for_readout_training",
#       "value": true
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "capacity_matched",
#       "op": "eq",
#       "pointer": "/capacity_matched",
#       "value": true
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "reference_unchanged",
#       "op": "eq",
#       "pointer": "/integrity/reference_checkpoint_unchanged",
#       "value": true
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "phase_unchanged",
#       "op": "eq",
#       "pointer": "/integrity/selected_checkpoint_unchanged",
#       "value": true
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "input_files_unchanged",
#       "op": "eq",
#       "pointer": "/integrity/input_files_unchanged",
#       "value": true
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "m8_closed",
#       "op": "eq",
#       "pointer": "/m8_final_horizons_exposed",
#       "value": false
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "m3_closed",
#       "op": "eq",
#       "pointer": "/M3_authorized_by_results",
#       "value": false
#     },
#     {
#       "artifact": "runs/m2_answer_path_challenge/result.json",
#       "name": "no_phase_superiority_claim",
#       "op": "eq",
#       "pointer": "/phase_superiority_claimed",
#       "value": false
#     }
#   ],
#   "resources": {
#     "device": "cpu",
#     "dtype": "float32",
#     "fresh_native_conditions_per_example": 2,
#     "gpu_required": false,
#     "historical_fit_native_conditions_per_example": 2,
#     "maximum_runtime_minutes": 90,
#     "readout_epochs": 10,
#     "threads": 1
#   },
#   "compute": null,
#   "prerequisites": [
#     "M2-E004/v001 is accepted under ADR-0012 only as a completed target/shortcut audit.",
#     "The M0 and selected Phase checkpoint hashes and the fresh-development lock match the registered inputs.",
#     "The support thresholds, intervention map, readout budget and seeds are fixed before the scientific run.",
#     "M3 and M8 remain closed throughout this experiment.",
#     "The output directory does not already exist."
#   ],
#   "dependencies": null,
#   "scientific_scope": "M2 development challenge validation and descriptive readout audit only. Passing support gates does not establish Phase superiority, Phase causality, native answer improvement, final-horizon generalization, M2 completion or M3 authorization.",
#   "timeout_seconds": 6000,
#   "research_track": null,
#   "paired_question_id": null,
#   "related_experiments": null,
#   "research_questions": null
# }
# ```
#
# Protocol SHA-256: `ab64c886169b35a0eac9a27dde49e170cf70e19dd72a80df07e7c3aa5e557e2f`
#
# | معیار | فایل و مسیر مقدار | عملگر | مقدار لازم |
# |---|---|---|---|
# | challenge_complete | runs/m2_answer_path_challenge/result.json/challenge_panel_complete | eq | true |
# | challenge_support_validated | runs/m2_answer_path_challenge/result.json/challenge_panel_suitable_for_answer_path_readout | eq | true |
# | window_1_failures | runs/m2_answer_path_challenge/result.json/windows/window_1/support/answer_failures | ge | 4 |
# | window_2_failures | runs/m2_answer_path_challenge/result.json/windows/window_2/support/answer_failures | ge | 4 |
# | window_1_successes | runs/m2_answer_path_challenge/result.json/windows/window_1/support/answer_successes | ge | 4 |
# | window_2_successes | runs/m2_answer_path_challenge/result.json/windows/window_2/support/answer_successes | ge | 4 |
# | window_1_chain_degradation | runs/m2_answer_path_challenge/result.json/windows/window_1/support/event_chain_degradations | ge | 4 |
# | window_2_chain_degradation | runs/m2_answer_path_challenge/result.json/windows/window_2/support/event_chain_degradations | ge | 4 |
# | window_1_margin_variation | runs/m2_answer_path_challenge/result.json/windows/window_1/support/response_margin_drop_std | ge | 1e-06 |
# | window_2_margin_variation | runs/m2_answer_path_challenge/result.json/windows/window_2/support/response_margin_drop_std | ge | 1e-06 |
# | fresh_targets_not_used | runs/m2_answer_path_challenge/result.json/fresh_targets_used_for_training_selection_or_tuning | eq | false |
# | fresh_lock_match | runs/m2_answer_path_challenge/result.json/integrity/fresh_lock_match | eq | true |
# | raw_text_disjoint | runs/m2_answer_path_challenge/result.json/integrity/raw_text_disjoint_from_m0_training | eq | true |
# | pair_disjoint | runs/m2_answer_path_challenge/result.json/integrity/counterfactual_pair_disjoint_from_m0_training | eq | true |
# | windows_pair_disjoint | runs/m2_answer_path_challenge/result.json/integrity/confirmation_windows_pair_disjoint | eq | true |
# | fit_monitor_disjoint | runs/m2_answer_path_challenge/result.json/integrity/historical_fit_monitor_disjoint | eq | true |
# | historical_training_only | runs/m2_answer_path_challenge/result.json/integrity/historical_targets_only_for_readout_training | eq | true |
# | capacity_matched | runs/m2_answer_path_challenge/result.json/capacity_matched | eq | true |
# | reference_unchanged | runs/m2_answer_path_challenge/result.json/integrity/reference_checkpoint_unchanged | eq | true |
# | phase_unchanged | runs/m2_answer_path_challenge/result.json/integrity/selected_checkpoint_unchanged | eq | true |
# | input_files_unchanged | runs/m2_answer_path_challenge/result.json/integrity/input_files_unchanged | eq | true |
# | m8_closed | runs/m2_answer_path_challenge/result.json/m8_final_horizons_exposed | eq | false |
# | m3_closed | runs/m2_answer_path_challenge/result.json/M3_authorized_by_results | eq | false |
# | no_phase_superiority_claim | runs/m2_answer_path_challenge/result.json/phase_superiority_claimed | eq | false |
#
# این اجرا به‌تنهایی مجوز عبور فاز نیست؛ خروجی باید به ریپو برگردد، با قفل‌های
# نسخه تطبیق داده شود، معیارها ارزیابی شوند و نتیجه‌گیری ثبت شود. شکست هم خروجی
# پژوهشی است و باید نگه‌داری شود. کنترل داده و checkpoint با SHA-256 انجام می‌شود.
#
# زمان و حافظه تابع تنظیمات پروتکل و runtime است؛ اگر در بخش resources یا compute مقدار ثبت
# نشده، برآورد هنوز معلوم نیست. محیط اجرا و مدت واقعی خودکار در نتیجه ثبت می‌شوند.

# %% [markdown]
# ## آماده‌سازی و دریافت نسخهٔ دقیق
#
# ابتدا runtime مطابق بخش resources یا compute انتخاب شود. دو فایل ساخته‌شده در ریپو را باهم
# بارگذاری کنید: ZIP سورس نسخه و `package.json` کنار همین نوت‌بوک. بسته عمداً
# checkpointها، نتایج قبلی و محیط مجازی را ندارد. این سلول hash کل بسته و تک‌تک
# فایل‌های آن را بررسی می‌کند و در پوشه‌ای تازه باز می‌کند.
#
# هیچ سرویس محلی نمی‌تواند صرف ساخت این نوت‌بوک، اجرای Colab را ادعا کند. اجرای
# واقعی با Run all در حساب پژوهشگر یا با ابزار مجاز و متصل انجام می‌شود.

# %%
from pathlib import Path, PurePosixPath
import hashlib, json, os, stat, sys, uuid, zipfile
from google.colab import files

EXPERIMENT_ID = 'M2-E005'
REVISION = 'v001'
PROTOCOL_SHA256 = 'ab64c886169b35a0eac9a27dde49e170cf70e19dd72a80df07e7c3aa5e557e2f'
REVISION_RELATIVE = 'research/experiments/M2-E005/v001'
uploaded = files.upload()
if 'package.json' not in uploaded:
    raise RuntimeError('Upload package.json and its exact source ZIP together')
lock = json.loads(uploaded['package.json'])
assert lock['experiment_id'] == EXPERIMENT_ID and lock['revision'] == REVISION
assert lock['protocol_sha256'] == PROTOCOL_SHA256
archive_name = lock['archive_name']
if archive_name not in uploaded:
    raise RuntimeError('Missing source archive: ' + archive_name)
source_archive = Path(archive_name)
actual_archive_sha = hashlib.sha256(source_archive.read_bytes()).hexdigest()
assert actual_archive_sha == lock['package_sha256'], 'Source ZIP SHA mismatch'
run_id = __import__('datetime').datetime.now(__import__('datetime').timezone.utc).strftime('%Y%m%dT%H%M%SZ') + '-' + uuid.uuid4().hex[:8]
ROOT = Path('/content/ergt_runs') / EXPERIMENT_ID / REVISION / run_id / 'source'
ROOT.mkdir(parents=True, exist_ok=False)
with zipfile.ZipFile(source_archive) as archive:
    seen = set()
    total = 0
    for item in archive.infolist():
        name = item.filename
        parts = name.split('/')
        if not name or '\\' in name or ':' in name or name.startswith('/') or any(p in ('', '.', '..') for p in parts):
            raise RuntimeError('Unsafe ZIP path: ' + name)
        if name.casefold() in seen or stat.S_ISLNK(item.external_attr >> 16):
            raise RuntimeError('Duplicate or symlink ZIP entry: ' + name)
        seen.add(name.casefold())
        total += item.file_size
        if total > 2 * 1024**3:
            raise RuntimeError('Unexpectedly large source archive')
    manifest_bytes = archive.read('PACKAGE_MANIFEST.json')
    assert hashlib.sha256(manifest_bytes).hexdigest() == lock['package_manifest_sha256']
    package_manifest = json.loads(manifest_bytes)
    assert set(archive.namelist()) == set(package_manifest['files']) | {'PACKAGE_MANIFEST.json'}
    archive.extractall(ROOT)
for relative, expected in package_manifest['files'].items():
    assert hashlib.sha256((ROOT / relative).read_bytes()).hexdigest() == expected, relative
REVISION_DIR = ROOT / REVISION_RELATIVE
assert hashlib.sha256((REVISION_DIR / 'protocol.json').read_bytes()).hexdigest() == PROTOCOL_SHA256
assert hashlib.sha256((REVISION_DIR / 'experiment.ipynb').read_bytes()).hexdigest() == lock['notebook_sha256']
sys.path.insert(0, str(ROOT))
os.environ['PYTHONDONTWRITEBYTECODE'] = '1'
sys.dont_write_bytecode = True
protocol = json.loads((REVISION_DIR / 'protocol.json').read_text(encoding='utf-8'))
print('Verified source:', EXPERIMENT_ID, REVISION, actual_archive_sha)

# %% [markdown]
# ## ورودی‌ها و پیش‌نیازها
#
# هر ورودی در `inputs` باید مسیر دقیق داخل پروژه، SHA-256 و محل دسترسی ثبت‌شده
# داشته باشد. برای فایل‌های بزرگ از مسیر Drive استفاده کنید؛ در غیر این صورت
# سلول برای هر فایل ثبت‌شده پنجرهٔ upload باز می‌کند. فایل‌ها تنها پس از تطبیق
# hash کپی می‌شوند. هیچ checkpoint با نام مشابه جایگزین نسخهٔ ثبت‌شده نمی‌شود.
#
# وابستگی تازه یا تغییر محیط باید در پروتکل نسخهٔ بعدی ثبت شود. این نوت‌بوک
# به‌صورت پنهان package نصب نمی‌کند. محیط و خروجی خطای وابستگی نیز در bundle
# اجرای ناموفق ثبت می‌شود.

# %%
from google.colab import drive
drive.mount('/content/drive')
import shutil
from research_tools.runner import safe_path, sha256

INPUT_ERRORS = []
for item in protocol.get('inputs', []):
    try:
        target = safe_path(ROOT, item['path'])
        target.parent.mkdir(parents=True, exist_ok=True)
        if target.is_file() and sha256(target) == item['sha256']:
            continue
        locator = item.get('uri', '')
        candidate = Path(locator.removeprefix('file://')) if locator.startswith(('/content/drive/', 'file:///content/drive/')) else None
        if candidate is not None and candidate.is_file():
            assert sha256(candidate) == item['sha256'], 'Drive input SHA mismatch: ' + item['path']
            shutil.copy2(candidate, target)
        else:
            print('Upload input:', item['path'], 'Registered locator:', locator)
            input_upload = files.upload()
            matched = [name for name, data in input_upload.items() if hashlib.sha256(data).hexdigest() == item['sha256']]
            if len(matched) != 1:
                raise RuntimeError('Exactly one uploaded input must match its registered SHA')
            target.write_bytes(input_upload[matched[0]])
        assert sha256(target) == item['sha256']
    except Exception as exc:
        INPUT_ERRORS.append(item['path'] + ': ' + str(exc))
print('Input errors; runner will export preflight failure evidence:' if INPUT_ERRORS else 'All input locks passed', INPUT_ERRORS)

# %% [markdown]
# ## اجرا و حفظ شواهد
#
# Runner دقیقاً command ثبت‌شده را اجرا می‌کند. stdout/stderr، محیط، زمان، کد
# خروج و تمام فایل‌های output_paths در ZIP نتیجه ثبت می‌شوند؛ شکست دستور هم
# bundle دارد. پوشهٔ نتیجه روی Drive برای هر اجرا مستقل است و بازنویسی نمی‌شود.
# در صورت قطع کامل runtime باید اجرای ناتمام ثبت و با run_id تازه تکرار شود.
#
# موفقیت اجرایی (`returncode=0`) به معنی موفقیت علمی یا عبور فاز نیست.

# %%
from research_tools.runner import run_protocol
DRIVE_RUN = Path('/content/drive/MyDrive/ERGT_Phi/research') / EXPERIMENT_ID / REVISION / run_id
DRIVE_RUN.mkdir(parents=True, exist_ok=False)
RESULT_BUNDLE = DRIVE_RUN / (run_id + '.zip')
run_manifest = run_protocol(ROOT, REVISION_DIR, RESULT_BUNDLE,
                            run_id=run_id, package_sha256=actual_archive_sha)
print(json.dumps(run_manifest, indent=2, ensure_ascii=False))
print('Preserved result bundle:', RESULT_BUNDLE)

# %% [markdown]
# ## برگشت نتیجه و تصمیم بعدی
#
# ZIP را دانلود و در `research/inbox/` ریپو قرار دهید. ایجنت باید آن را با دستور
# workflow import دریافت کند، hash و ارتباط پروتکل/نوت‌بوک/سورس را بررسی کند،
# و کنار همین revision گزارش تولید کند. سپس نتیجهٔ واقعی، کنترل‌ها، شکست‌ها و
# گزینه‌های بعدی در review و دفتر تصمیم معماری ثبت شوند. هر پیشرفت باید commit
# شود. اگر فایل نتیجه هنوز برنگشته، وضعیت «در انتظار نتیجه» است.
#
# شناسهٔ پیگیری: `M2-E005/v001`. برای تکرار یک نسخه run_id تازه لازم است؛ برای
# تغییر فرضیه، کد علمی یا معیار، revision تازه لازم است. این نوت‌بوک را برای
# دورزدن معیارها در Colab ویرایش نکنید.

# %%
files.download(str(RESULT_BUNDLE))
